# %%
import numpy as np
import pandas as pd
#import bar_chart_race_ as bcr
import plotly
import os
import colorsys

#df = pd.DataFrame({'A': [1, np.nan, 3, 4], 'B': [3, 4, np.nan, np.nan], 'C': [np.nan, 9, 3, 1]})
# df = df.fillna(0)
#print(np.array(range(1,11))-5)
# row = df[df.index==0].transpose()[0]
# row.index = np.array([1,2,3])
# print(row.values)
# print(type(row))
a = np.random.random((2,2))
print(a.max())
print(a.argmax())
print(a.flatten()[a.argmax()])

# steps_per_period = 2
# df.index = df.index * steps_per_period
# new_index = range(df.index[-1]+1)
# df= df.reindex(new_index)
# df = df.interpolate()
# print(df)
# df = df.rank(axis=1, method='first')
# df[df>2] = np.nan
# print(df)
# #df_out = pd.DataFrame({1: ['A', 'B', 'A', 'C'], 2:  ['B', 'C', 'C', 'A']})
# #print(df_out)

# s = df.stack().reset_index()
# df2 = pd.DataFrame(s)
# df2 = df2.pivot(index='level_0', columns=0, values='level_1')
# print(df2)

import plotly.graph_objects as go
animals=['giraffes', 'orangutans', 'monkeys']
data = go.Bar(y=animals, x=[20, 14, 23], orientation='h')
yaxis = dict(tickvals=animals, ticktext=animals, title='animals')
layout = go.Layout(yaxis=yaxis)
fig = go.Figure([data], layout)
fig.show()
# Out:
# 0.42640380623251084
# 1
# 0.42640380623251084
# 2

# %%
import numpy as np
import pandas as pd
labels = ["alpha", "beta", "gamma"]
df_vals = pd.DataFrame({'t1':[10,9,8], 't2':[7,6,5]})
df_ranks = pd.DataFrame({'t1':[0,1,2], 't2':[2,0,1]})  # 0-based IDs

additions = np.array([len(l)/4 for l in labels])
print(additions)
add_df_mat = additions[df_ranks.to_numpy().T]
print(add_df_mat)

total_lens = df_vals.to_numpy().T + add_df_mat
total_lens.max()
# Out:
# [1.25 1.   1.25]
# [[1.25 1.   1.25]
#  [1.25 1.25 1.  ]]
# np.float64(11.25)
