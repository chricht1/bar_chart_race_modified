# %%
import numpy as np
import pandas as pd

a = np.arange(5).astype(np.float64())#
b = a
b[0] = 10
a
#b = pd.DataFrame({'a':[0], 'b':[2], 'c':[3]})
# Out:
# array([10.,  1.,  2.,  3.,  4.])

# %%
import plotly.graph_objects as go
animals=['giraffes', 'orangutans', 'monkeys']
bar = go.Bar(x=[20, 14, 23], y=animals, orientation='h')
#fig = go.Figure([bar])
#fig.show()
print(np.array(bar.y))
# Out:
# ['giraffes' 'orangutans' 'monkeys']
